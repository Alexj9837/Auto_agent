# %%
from Moutain.model import Mountain
import matplotlib.pyplot as plt
import pandas as pd


n_robots = 3
n_Patient = 3
n_healers = 3
seed = 123
width = 50
height = 50
n_steps = 300

m = Mountain(n_robots, n_Patient, n_healers,
             width=width, height=height, seed=seed)

for i in range(n_steps):
    m.step()

m_df = m.datacollector.get_model_vars_dataframe()
ag_df = m.datacollector.get_agent_vars_dataframe()
# Out:
# 49 4
# ag_ 0  action: move_mountain  State: 0
# 92.9
# 49 18
# ag_ 1  action: move_mountain  State: 0
# 92.9
# 49 6
# ag_ 2  action: move_mountain  State: 0
# 92.9
# ag_ 3  action: wait  State: 0
# ag_ 4  action: wait  State: 0
# ag_ 5  action: wait  State: 0
# running... 0
# 48 5
# ag_ 0  action: move_mountain  State: 0
# 92.80000000000001
# 48 19
# ag_ 1  action: move_mountain  State: 0
# 92.80000000000001
# 48 7
# ag_ 2  action: move_mountain  State: 0
# 92.80000000000001
# ag_ 3  action: wait  State: 0
# ag_ 4  action: wait  State: 0
# ag_ 5  action: wait  State: 0
# running... 0
# 47 6
# ag_ 0  action: move_mountain  State: 0
# 92.70000000000002
# 47 20
# ag_ 1  action: move_mountain  State: 0
# 92.70000000000002
# 47 8
# ag_ 2  action: move_mountain  State: 0
# 92.70000000000002
# ag_ 3  action: wait  State: 0
# ag_ 4  action: wait  State: 0
# ag_ 5  action: wait  State: 0
# running... 0
# 46 7
# ag_ 0  action: move_mountain  State: 0
# 92.60000000000002
# 46 21
# ...

# %% [markdown]
# # Battery drain for each agent
#
# A brief elplaination of the below plots, the first three track the battery of the searching robot and the next three are of the healing drone.

# %%
ag_df = ag_df.dropna()
ag_df.groupby("AgentID").plot(y="battery")
# Out:
# AgentID
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# # Pending patient and sthe steps taken
#
# The below graph shows the steps taken before all three patients are found, this is displayed by takening the pending patient list on the Y axis and the step along X axis

# %%
m_df.plot()
# Out:
# <AxesSubplot:>
